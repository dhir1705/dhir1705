# %% [markdown]
# <a href="https://colab.research.google.com/github/dhir1705/dhir1705/blob/main/1_Neural_Network_Back_Propagation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install tensorflow

# %%
#!pip install keras

# %%
# Create your first MLP in Keras
from keras.models import Sequential
from keras.layers import Dense
import numpy

# %%
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load pima indians dataset
dataset = numpy.loadtxt("/content/pima-indians-diabetes.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]

# %%
# create model
model = Sequential()
model.add(Dense(12, input_dim=8,  activation='relu'))
model.add(Dense(8,  activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Fit the model
model.fit(X, Y, validation_split=0.33, epochs=250, batch_size=20)
# Out:
# Epoch 1/250
# 26/26 [==============================] - 1s 9ms/step - loss: 0.6703 - accuracy: 0.6245 - val_loss: 0.6373 - val_accuracy: 0.6457
# Epoch 2/250
# 26/26 [==============================] - 0s 3ms/step - loss: 0.6337 - accuracy: 0.6556 - val_loss: 0.6344 - val_accuracy: 0.6378
# Epoch 3/250
# 26/26 [==============================] - 0s 3ms/step - loss: 0.6203 - accuracy: 0.6654 - val_loss: 0.6356 - val_accuracy: 0.6299
# Epoch 4/250
# 26/26 [==============================] - 0s 3ms/step - loss: 0.6148 - accuracy: 0.6420 - val_loss: 0.6346 - val_accuracy: 0.6457
# Epoch 5/250
# 26/26 [==============================] - 0s 3ms/step - loss: 0.6108 - accuracy: 0.6654 - val_loss: 0.6346 - val_accuracy: 0.6260
# Epoch 6/250
# 26/26 [==============================] - 0s 3ms/step - loss: 0.6086 - accuracy: 0.6809 - val_loss: 0.6359 - val_accuracy: 0.6142
# Epoch 7/250
# ...

# %%
# evaluate the model
scores = model.evaluate(X, Y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4993 - accuracy: 0.7500
# accuracy: 75.00%
